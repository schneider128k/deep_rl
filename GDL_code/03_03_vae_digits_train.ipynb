# %% [markdown]
# # VAE Training

# %% [markdown]
# ## Imports

# %%
import os

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist
# Out:
# Using TensorFlow backend.

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %% [markdown]
# ## Data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## Architecture

# %%
vae = VariationalAutoencoder(
    input_dim = (28, 28, 1)
    , encoder_conv_filters = [32, 64, 64, 64]
    , encoder_conv_kernel_size = [3, 3, 3, 3]
    , encoder_conv_strides = [1, 2, 2, 1]
    , decoder_conv_t_filters = [64, 64, 32, 1]
    , decoder_conv_t_kernel_size = [3, 3, 3, 3]
    , decoder_conv_t_strides = [1, 2, 2, 1]
    , z_dim = 2
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))
# Out:
# WARNING:tensorflow:From C:\anaconda\envs\gym\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\anaconda\envs\gym\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\anaconda\envs\gym\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\anaconda\envs\gym\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.

# %%
vae.encoder.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3136)         0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten_1[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten_1[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000

# %%
vae.compile(LEARNING_RATE, R_LOSS_FACTOR)
# Out:
# WARNING:tensorflow:From C:\anaconda\envs\gym\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train, 
    batch_size=BATCH_SIZE, 
    epochs=EPOCHS, 
    run_folder=RUN_FOLDER, 
    print_every_n_batches=PRINT_EVERY_N_BATCHES, 
    initial_epoch=INITIAL_EPOCH
)
# Out:
# WARNING:tensorflow:From C:\anaconda\envs\gym\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 58.9032 - vae_r_loss: 55.7228 - vae_kl_loss: 3.1804
#
# Epoch 00001: saving model to run/vae/0002_digits\weights/weights-001-58.90.h5
#
# Epoch 00001: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 2/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 51.8501 - vae_r_loss: 47.9027 - vae_kl_loss: 3.9473
#
# Epoch 00002: saving model to run/vae/0002_digits\weights/weights-002-51.85.h5
#
# Epoch 00002: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 3/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 50.1740 - vae_r_loss: 45.8675 - vae_kl_loss: 4.3066
#
# Epoch 00003: saving model to run/vae/0002_digits\weights/weights-003-50.17.h5
#
# Epoch 00003: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 4/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 49.1573 - vae_r_loss: 44.6609 - vae_kl_loss: 4.4964
#
# Epoch 00004: saving model to run/vae/0002_digits\weights/weights-004-49.16.h5
#
# Epoch 00004: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 5/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 48.5294 - vae_r_loss: 43.9117 - vae_kl_loss: 4.6178
#
# Epoch 00005: saving model to run/vae/0002_digits\weights/weights-005-48.53.h5
#
# Epoch 00005: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 6/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 48.0806 - vae_r_loss: 43.3926 - vae_kl_loss: 4.6879
#
# Epoch 00006: saving model to run/vae/0002_digits\weights/weights-006-48.08.h5
#
# Epoch 00006: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 7/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 47.7391 - vae_r_loss: 42.9701 - vae_kl_loss: 4.7690
#
# Epoch 00007: saving model to run/vae/0002_digits\weights/weights-007-47.74.h5
#
# Epoch 00007: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 8/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 47.4122 - vae_r_loss: 42.6093 - vae_kl_loss: 4.8029
#
# Epoch 00008: saving model to run/vae/0002_digits\weights/weights-008-47.41.h5
#
# Epoch 00008: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 9/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 47.1959 - vae_r_loss: 42.3458 - vae_kl_loss: 4.8500
#
# Epoch 00009: saving model to run/vae/0002_digits\weights/weights-009-47.20.h5
#
# Epoch 00009: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 10/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 46.9799 - vae_r_loss: 42.1049 - vae_kl_loss: 4.8749
#
# Epoch 00010: saving model to run/vae/0002_digits\weights/weights-010-46.98.h5
#
# Epoch 00010: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 11/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 46.8211 - vae_r_loss: 41.9168 - vae_kl_loss: 4.9043
#
# Epoch 00011: saving model to run/vae/0002_digits\weights/weights-011-46.82.h5
#
# Epoch 00011: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 12/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 46.6442 - vae_r_loss: 41.7158 - vae_kl_loss: 4.9285
#
# Epoch 00012: saving model to run/vae/0002_digits\weights/weights-012-46.64.h5
#
# Epoch 00012: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 13/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 46.4968 - vae_r_loss: 41.5499 - vae_kl_loss: 4.9468
#
# Epoch 00013: saving model to run/vae/0002_digits\weights/weights-013-46.50.h5
#
# Epoch 00013: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 14/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 46.3700 - vae_r_loss: 41.4161 - vae_kl_loss: 4.9539
#
# Epoch 00014: saving model to run/vae/0002_digits\weights/weights-014-46.37.h5
#
# Epoch 00014: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 15/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 46.2804 - vae_r_loss: 41.2958 - vae_kl_loss: 4.9847
#
# Epoch 00015: saving model to run/vae/0002_digits\weights/weights-015-46.28.h5
#
# Epoch 00015: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 16/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 46.1493 - vae_r_loss: 41.1473 - vae_kl_loss: 5.0020
#
# Epoch 00016: saving model to run/vae/0002_digits\weights/weights-016-46.15.h5
#
# Epoch 00016: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 17/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 46.0584 - vae_r_loss: 41.0337 - vae_kl_loss: 5.0247
#
# Epoch 00017: saving model to run/vae/0002_digits\weights/weights-017-46.06.h5
#
# Epoch 00017: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 18/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.9845 - vae_r_loss: 40.9564 - vae_kl_loss: 5.0282
#
# Epoch 00018: saving model to run/vae/0002_digits\weights/weights-018-45.98.h5
#
# Epoch 00018: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 19/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.9271 - vae_r_loss: 40.8874 - vae_kl_loss: 5.0396
#
# Epoch 00019: saving model to run/vae/0002_digits\weights/weights-019-45.93.h5
#
# Epoch 00019: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 20/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.8153 - vae_r_loss: 40.7642 - vae_kl_loss: 5.0511
#
# Epoch 00020: saving model to run/vae/0002_digits\weights/weights-020-45.82.h5
#
# Epoch 00020: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 21/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.7501 - vae_r_loss: 40.6949 - vae_kl_loss: 5.0553
#
# Epoch 00021: saving model to run/vae/0002_digits\weights/weights-021-45.75.h5
#
# Epoch 00021: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 22/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.6936 - vae_r_loss: 40.6107 - vae_kl_loss: 5.0829
#
# Epoch 00022: saving model to run/vae/0002_digits\weights/weights-022-45.69.h5
#
# Epoch 00022: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 23/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.6012 - vae_r_loss: 40.5182 - vae_kl_loss: 5.0829
#
# Epoch 00023: saving model to run/vae/0002_digits\weights/weights-023-45.60.h5
#
# Epoch 00023: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 24/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.5964 - vae_r_loss: 40.4997 - vae_kl_loss: 5.0967
#
# Epoch 00024: saving model to run/vae/0002_digits\weights/weights-024-45.60.h5
#
# Epoch 00024: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 25/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.5105 - vae_r_loss: 40.4176 - vae_kl_loss: 5.0929
#
# Epoch 00025: saving model to run/vae/0002_digits\weights/weights-025-45.51.h5
#
# Epoch 00025: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 26/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.5008 - vae_r_loss: 40.3903 - vae_kl_loss: 5.1104
#
# Epoch 00026: saving model to run/vae/0002_digits\weights/weights-026-45.50.h5
#
# Epoch 00026: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 27/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.3998 - vae_r_loss: 40.2767 - vae_kl_loss: 5.1231
#
# Epoch 00027: saving model to run/vae/0002_digits\weights/weights-027-45.40.h5
#
# Epoch 00027: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 28/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.3794 - vae_r_loss: 40.2544 - vae_kl_loss: 5.1250
#
# Epoch 00028: saving model to run/vae/0002_digits\weights/weights-028-45.38.h5
#
# Epoch 00028: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 29/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.3225 - vae_r_loss: 40.1903 - vae_kl_loss: 5.1321
#
# Epoch 00029: saving model to run/vae/0002_digits\weights/weights-029-45.32.h5
#
# Epoch 00029: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 30/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.2821 - vae_r_loss: 40.1470 - vae_kl_loss: 5.1350
#
# Epoch 00030: saving model to run/vae/0002_digits\weights/weights-030-45.28.h5
#
# Epoch 00030: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 31/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.2744 - vae_r_loss: 40.1302 - vae_kl_loss: 5.1442
#
# Epoch 00031: saving model to run/vae/0002_digits\weights/weights-031-45.27.h5
#
# Epoch 00031: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 32/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.1782 - vae_r_loss: 40.0350 - vae_kl_loss: 5.1432
#
# Epoch 00032: saving model to run/vae/0002_digits\weights/weights-032-45.18.h5
#
# Epoch 00032: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 33/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.1782 - vae_r_loss: 40.0155 - vae_kl_loss: 5.1627
#
# Epoch 00033: saving model to run/vae/0002_digits\weights/weights-033-45.18.h5
#
# Epoch 00033: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 34/200
# 60000/60000 [==============================] - 14s 237us/step - loss: 45.1171 - vae_r_loss: 39.9567 - vae_kl_loss: 5.1605
#
# Epoch 00034: saving model to run/vae/0002_digits\weights/weights-034-45.12.h5
#
# Epoch 00034: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 35/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.0896 - vae_r_loss: 39.9327 - vae_kl_loss: 5.1569
#
# Epoch 00035: saving model to run/vae/0002_digits\weights/weights-035-45.09.h5
#
# Epoch 00035: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 36/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 45.0634 - vae_r_loss: 39.9035 - vae_kl_loss: 5.1599
#
# Epoch 00036: saving model to run/vae/0002_digits\weights/weights-036-45.06.h5
#
# Epoch 00036: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 37/200
# 60000/60000 [==============================] - 14s 237us/step - loss: 45.0057 - vae_r_loss: 39.8454 - vae_kl_loss: 5.1603
#
# Epoch 00037: saving model to run/vae/0002_digits\weights/weights-037-45.01.h5
#
# Epoch 00037: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 38/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 45.0069 - vae_r_loss: 39.8244 - vae_kl_loss: 5.1825
#
# Epoch 00038: saving model to run/vae/0002_digits\weights/weights-038-45.01.h5
#
# Epoch 00038: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 39/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 44.9410 - vae_r_loss: 39.7549 - vae_kl_loss: 5.1860
#
# Epoch 00039: saving model to run/vae/0002_digits\weights/weights-039-44.94.h5
#
# Epoch 00039: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 40/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.9436 - vae_r_loss: 39.7338 - vae_kl_loss: 5.2098
#
# Epoch 00040: saving model to run/vae/0002_digits\weights/weights-040-44.94.h5
#
# Epoch 00040: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 41/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.8732 - vae_r_loss: 39.6738 - vae_kl_loss: 5.1995
#
# Epoch 00041: saving model to run/vae/0002_digits\weights/weights-041-44.87.h5
#
# Epoch 00041: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 42/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.8746 - vae_r_loss: 39.6816 - vae_kl_loss: 5.1930
#
# Epoch 00042: saving model to run/vae/0002_digits\weights/weights-042-44.87.h5
#
# Epoch 00042: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 43/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.8134 - vae_r_loss: 39.6140 - vae_kl_loss: 5.1994
#
# Epoch 00043: saving model to run/vae/0002_digits\weights/weights-043-44.81.h5
#
# Epoch 00043: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 44/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 44.7683 - vae_r_loss: 39.5556 - vae_kl_loss: 5.2127
#
# Epoch 00044: saving model to run/vae/0002_digits\weights/weights-044-44.77.h5
#
# Epoch 00044: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 45/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.7994 - vae_r_loss: 39.5796 - vae_kl_loss: 5.2198
#
# Epoch 00045: saving model to run/vae/0002_digits\weights/weights-045-44.80.h5
#
# Epoch 00045: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 46/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 44.7767 - vae_r_loss: 39.5665 - vae_kl_loss: 5.2102
#
# Epoch 00046: saving model to run/vae/0002_digits\weights/weights-046-44.78.h5
#
# Epoch 00046: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 47/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 44.7381 - vae_r_loss: 39.5105 - vae_kl_loss: 5.2275
#
# Epoch 00047: saving model to run/vae/0002_digits\weights/weights-047-44.74.h5
#
# Epoch 00047: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 48/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.7357 - vae_r_loss: 39.4995 - vae_kl_loss: 5.2362
#
# Epoch 00048: saving model to run/vae/0002_digits\weights/weights-048-44.74.h5
#
# Epoch 00048: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 49/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.6908 - vae_r_loss: 39.4619 - vae_kl_loss: 5.2290
#
# Epoch 00049: saving model to run/vae/0002_digits\weights/weights-049-44.69.h5
#
# Epoch 00049: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 50/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 44.6467 - vae_r_loss: 39.4184 - vae_kl_loss: 5.2284
#
# Epoch 00050: saving model to run/vae/0002_digits\weights/weights-050-44.65.h5
#
# Epoch 00050: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 51/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 44.6202 - vae_r_loss: 39.3849 - vae_kl_loss: 5.2353
#
# Epoch 00051: saving model to run/vae/0002_digits\weights/weights-051-44.62.h5
#
# Epoch 00051: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 52/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 44.6166 - vae_r_loss: 39.3891 - vae_kl_loss: 5.2276
#
# Epoch 00052: saving model to run/vae/0002_digits\weights/weights-052-44.62.h5
#
# Epoch 00052: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 53/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 44.6127 - vae_r_loss: 39.3588 - vae_kl_loss: 5.2540
#
# Epoch 00053: saving model to run/vae/0002_digits\weights/weights-053-44.61.h5
#
# Epoch 00053: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 54/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 44.5705 - vae_r_loss: 39.3297 - vae_kl_loss: 5.2409
#
# Epoch 00054: saving model to run/vae/0002_digits\weights/weights-054-44.57.h5
#
# Epoch 00054: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 55/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 44.5594 - vae_r_loss: 39.3029 - vae_kl_loss: 5.2565
#
# Epoch 00055: saving model to run/vae/0002_digits\weights/weights-055-44.56.h5
#
# Epoch 00055: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 56/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 44.5236 - vae_r_loss: 39.2626 - vae_kl_loss: 5.2610
#
# Epoch 00056: saving model to run/vae/0002_digits\weights/weights-056-44.52.h5
#
# Epoch 00056: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 57/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.5184 - vae_r_loss: 39.2632 - vae_kl_loss: 5.2552
#
# Epoch 00057: saving model to run/vae/0002_digits\weights/weights-057-44.52.h5
#
# Epoch 00057: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 58/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 44.4768 - vae_r_loss: 39.2305 - vae_kl_loss: 5.2462
#
# Epoch 00058: saving model to run/vae/0002_digits\weights/weights-058-44.48.h5
#
# Epoch 00058: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 59/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 44.4797 - vae_r_loss: 39.2239 - vae_kl_loss: 5.2558
#
# Epoch 00059: saving model to run/vae/0002_digits\weights/weights-059-44.48.h5
#
# Epoch 00059: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 60/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.4537 - vae_r_loss: 39.1878 - vae_kl_loss: 5.2659
#
# Epoch 00060: saving model to run/vae/0002_digits\weights/weights-060-44.45.h5
#
# Epoch 00060: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 61/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 44.4195 - vae_r_loss: 39.1539 - vae_kl_loss: 5.2656
#
# Epoch 00061: saving model to run/vae/0002_digits\weights/weights-061-44.42.h5
#
# Epoch 00061: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 62/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.4251 - vae_r_loss: 39.1502 - vae_kl_loss: 5.2749
#
# Epoch 00062: saving model to run/vae/0002_digits\weights/weights-062-44.43.h5
#
# Epoch 00062: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 63/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.3720 - vae_r_loss: 39.0955 - vae_kl_loss: 5.2765
#
# Epoch 00063: saving model to run/vae/0002_digits\weights/weights-063-44.37.h5
#
# Epoch 00063: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 64/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.3919 - vae_r_loss: 39.1027 - vae_kl_loss: 5.2892
#
# Epoch 00064: saving model to run/vae/0002_digits\weights/weights-064-44.39.h5
#
# Epoch 00064: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 65/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 44.3583 - vae_r_loss: 39.0704 - vae_kl_loss: 5.2880
#
# Epoch 00065: saving model to run/vae/0002_digits\weights/weights-065-44.36.h5
#
# Epoch 00065: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 66/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 44.3352 - vae_r_loss: 39.0573 - vae_kl_loss: 5.2779
#
# Epoch 00066: saving model to run/vae/0002_digits\weights/weights-066-44.34.h5
#
# Epoch 00066: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 67/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 44.3203 - vae_r_loss: 39.0229 - vae_kl_loss: 5.2975
#
# Epoch 00067: saving model to run/vae/0002_digits\weights/weights-067-44.32.h5
#
# Epoch 00067: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 68/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.3403 - vae_r_loss: 39.0570 - vae_kl_loss: 5.2834
#
# Epoch 00068: saving model to run/vae/0002_digits\weights/weights-068-44.34.h5
#
# Epoch 00068: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 69/200
# 60000/60000 [==============================] - 14s 230us/step - loss: 44.3127 - vae_r_loss: 39.0241 - vae_kl_loss: 5.2885
#
# Epoch 00069: saving model to run/vae/0002_digits\weights/weights-069-44.31.h5
#
# Epoch 00069: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 70/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.3031 - vae_r_loss: 38.9964 - vae_kl_loss: 5.3067
#
# Epoch 00070: saving model to run/vae/0002_digits\weights/weights-070-44.30.h5
#
# Epoch 00070: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 71/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.2428 - vae_r_loss: 38.9517 - vae_kl_loss: 5.2910
#
# Epoch 00071: saving model to run/vae/0002_digits\weights/weights-071-44.24.h5
#
# Epoch 00071: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 72/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.2747 - vae_r_loss: 38.9677 - vae_kl_loss: 5.3070
#
# Epoch 00072: saving model to run/vae/0002_digits\weights/weights-072-44.27.h5
#
# Epoch 00072: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 73/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 44.2243 - vae_r_loss: 38.9237 - vae_kl_loss: 5.3007
#
# Epoch 00073: saving model to run/vae/0002_digits\weights/weights-073-44.22.h5
#
# Epoch 00073: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 74/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.2270 - vae_r_loss: 38.9239 - vae_kl_loss: 5.3031
#
# Epoch 00074: saving model to run/vae/0002_digits\weights/weights-074-44.23.h5
#
# Epoch 00074: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 75/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 44.2210 - vae_r_loss: 38.9069 - vae_kl_loss: 5.3141
#
# Epoch 00075: saving model to run/vae/0002_digits\weights/weights-075-44.22.h5
#
# Epoch 00075: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 76/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.1701 - vae_r_loss: 38.8509 - vae_kl_loss: 5.3192
#
# Epoch 00076: saving model to run/vae/0002_digits\weights/weights-076-44.17.h5
#
# Epoch 00076: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 77/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.2096 - vae_r_loss: 38.8886 - vae_kl_loss: 5.3210
#
# Epoch 00077: saving model to run/vae/0002_digits\weights/weights-077-44.21.h5
#
# Epoch 00077: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 78/200
# 60000/60000 [==============================] - 14s 230us/step - loss: 44.1534 - vae_r_loss: 38.8386 - vae_kl_loss: 5.3149
#
# Epoch 00078: saving model to run/vae/0002_digits\weights/weights-078-44.15.h5
#
# Epoch 00078: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 79/200
# 60000/60000 [==============================] - 14s 239us/step - loss: 44.1498 - vae_r_loss: 38.8367 - vae_kl_loss: 5.3130
#
# Epoch 00079: saving model to run/vae/0002_digits\weights/weights-079-44.15.h5
#
# Epoch 00079: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 80/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 44.1233 - vae_r_loss: 38.8059 - vae_kl_loss: 5.3174
#
# Epoch 00080: saving model to run/vae/0002_digits\weights/weights-080-44.12.h5
#
# Epoch 00080: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 81/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 44.1165 - vae_r_loss: 38.7965 - vae_kl_loss: 5.3201
#
# Epoch 00081: saving model to run/vae/0002_digits\weights/weights-081-44.12.h5
#
# Epoch 00081: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 82/200
# 60000/60000 [==============================] - 14s 237us/step - loss: 44.0953 - vae_r_loss: 38.7734 - vae_kl_loss: 5.3219
#
# Epoch 00082: saving model to run/vae/0002_digits\weights/weights-082-44.10.h5
#
# Epoch 00082: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 83/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 44.0845 - vae_r_loss: 38.7739 - vae_kl_loss: 5.3106
#
# Epoch 00083: saving model to run/vae/0002_digits\weights/weights-083-44.08.h5
#
# Epoch 00083: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 84/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 44.0945 - vae_r_loss: 38.7607 - vae_kl_loss: 5.3338
#
# Epoch 00084: saving model to run/vae/0002_digits\weights/weights-084-44.09.h5
#
# Epoch 00084: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 85/200
# 60000/60000 [==============================] - 14s 230us/step - loss: 44.0605 - vae_r_loss: 38.7272 - vae_kl_loss: 5.3333
#
# Epoch 00085: saving model to run/vae/0002_digits\weights/weights-085-44.06.h5
#
# Epoch 00085: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 86/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 44.0853 - vae_r_loss: 38.7429 - vae_kl_loss: 5.3424
#
# Epoch 00086: saving model to run/vae/0002_digits\weights/weights-086-44.09.h5
#
# Epoch 00086: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 87/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 44.0478 - vae_r_loss: 38.7177 - vae_kl_loss: 5.3301
#
# Epoch 00087: saving model to run/vae/0002_digits\weights/weights-087-44.05.h5
#
# Epoch 00087: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 88/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 44.0352 - vae_r_loss: 38.7047 - vae_kl_loss: 5.3305
#
# Epoch 00088: saving model to run/vae/0002_digits\weights/weights-088-44.04.h5
#
# Epoch 00088: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 89/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 44.0027 - vae_r_loss: 38.6667 - vae_kl_loss: 5.3360
#
# Epoch 00089: saving model to run/vae/0002_digits\weights/weights-089-44.00.h5
#
# Epoch 00089: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 90/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 44.0197 - vae_r_loss: 38.6798 - vae_kl_loss: 5.3399
#
# Epoch 00090: saving model to run/vae/0002_digits\weights/weights-090-44.02.h5
#
# Epoch 00090: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 91/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 44.0264 - vae_r_loss: 38.6825 - vae_kl_loss: 5.3439
#
# Epoch 00091: saving model to run/vae/0002_digits\weights/weights-091-44.03.h5
#
# Epoch 00091: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 92/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 43.9525 - vae_r_loss: 38.6180 - vae_kl_loss: 5.3344
#
# Epoch 00092: saving model to run/vae/0002_digits\weights/weights-092-43.95.h5
#
# Epoch 00092: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 93/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.9897 - vae_r_loss: 38.6313 - vae_kl_loss: 5.3584
#
# Epoch 00093: saving model to run/vae/0002_digits\weights/weights-093-43.99.h5
#
# Epoch 00093: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 94/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.9593 - vae_r_loss: 38.6159 - vae_kl_loss: 5.3434
#
# Epoch 00094: saving model to run/vae/0002_digits\weights/weights-094-43.96.h5
#
# Epoch 00094: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 95/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.9765 - vae_r_loss: 38.6085 - vae_kl_loss: 5.3680
#
# Epoch 00095: saving model to run/vae/0002_digits\weights/weights-095-43.98.h5
#
# Epoch 00095: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 96/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.9400 - vae_r_loss: 38.5750 - vae_kl_loss: 5.3650
#
# Epoch 00096: saving model to run/vae/0002_digits\weights/weights-096-43.94.h5
#
# Epoch 00096: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 97/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.9378 - vae_r_loss: 38.5781 - vae_kl_loss: 5.3598
#
# Epoch 00097: saving model to run/vae/0002_digits\weights/weights-097-43.94.h5
#
# Epoch 00097: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 98/200
# 60000/60000 [==============================] - 14s 230us/step - loss: 43.9212 - vae_r_loss: 38.5651 - vae_kl_loss: 5.3561
#
# Epoch 00098: saving model to run/vae/0002_digits\weights/weights-098-43.92.h5
#
# Epoch 00098: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 99/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 43.9118 - vae_r_loss: 38.5530 - vae_kl_loss: 5.3588
#
# Epoch 00099: saving model to run/vae/0002_digits\weights/weights-099-43.91.h5
#
# Epoch 00099: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 100/200
# 60000/60000 [==============================] - 14s 238us/step - loss: 43.9169 - vae_r_loss: 38.5596 - vae_kl_loss: 5.3573
#
# Epoch 00100: saving model to run/vae/0002_digits\weights/weights-100-43.92.h5
#
# Epoch 00100: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 101/200
# 60000/60000 [==============================] - 14s 237us/step - loss: 43.8902 - vae_r_loss: 38.5153 - vae_kl_loss: 5.3749
#
# Epoch 00101: saving model to run/vae/0002_digits\weights/weights-101-43.89.h5
#
# Epoch 00101: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 102/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.8906 - vae_r_loss: 38.5158 - vae_kl_loss: 5.3748
#
# Epoch 00102: saving model to run/vae/0002_digits\weights/weights-102-43.89.h5
#
# Epoch 00102: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 103/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 43.8637 - vae_r_loss: 38.5036 - vae_kl_loss: 5.3601
#
# Epoch 00103: saving model to run/vae/0002_digits\weights/weights-103-43.86.h5
#
# Epoch 00103: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 104/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.8626 - vae_r_loss: 38.4884 - vae_kl_loss: 5.3742
#
# Epoch 00104: saving model to run/vae/0002_digits\weights/weights-104-43.86.h5
#
# Epoch 00104: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 105/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.8537 - vae_r_loss: 38.4786 - vae_kl_loss: 5.3751
#
# Epoch 00105: saving model to run/vae/0002_digits\weights/weights-105-43.85.h5
#
# Epoch 00105: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 106/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.8397 - vae_r_loss: 38.4631 - vae_kl_loss: 5.3766
#
# Epoch 00106: saving model to run/vae/0002_digits\weights/weights-106-43.84.h5
#
# Epoch 00106: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 107/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 43.8459 - vae_r_loss: 38.4593 - vae_kl_loss: 5.3866
#
# Epoch 00107: saving model to run/vae/0002_digits\weights/weights-107-43.85.h5
#
# Epoch 00107: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 108/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.8438 - vae_r_loss: 38.4673 - vae_kl_loss: 5.3765
#
# Epoch 00108: saving model to run/vae/0002_digits\weights/weights-108-43.84.h5
#
# Epoch 00108: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 109/200
# 60000/60000 [==============================] - 14s 238us/step - loss: 43.7948 - vae_r_loss: 38.4142 - vae_kl_loss: 5.3806
#
# Epoch 00109: saving model to run/vae/0002_digits\weights/weights-109-43.79.h5
#
# Epoch 00109: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 110/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 43.7965 - vae_r_loss: 38.4265 - vae_kl_loss: 5.3700
#
# Epoch 00110: saving model to run/vae/0002_digits\weights/weights-110-43.80.h5
#
# Epoch 00110: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 111/200
# 60000/60000 [==============================] - 14s 229us/step - loss: 43.8057 - vae_r_loss: 38.4196 - vae_kl_loss: 5.3861
#
# Epoch 00111: saving model to run/vae/0002_digits\weights/weights-111-43.81.h5
#
# Epoch 00111: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 112/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.7782 - vae_r_loss: 38.3958 - vae_kl_loss: 5.3824
#
# Epoch 00112: saving model to run/vae/0002_digits\weights/weights-112-43.78.h5
#
# Epoch 00112: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 113/200
# 60000/60000 [==============================] - 14s 228us/step - loss: 43.8079 - vae_r_loss: 38.4064 - vae_kl_loss: 5.4014
#
# Epoch 00113: saving model to run/vae/0002_digits\weights/weights-113-43.81.h5
#
# Epoch 00113: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 114/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.7706 - vae_r_loss: 38.3771 - vae_kl_loss: 5.3935
#
# Epoch 00114: saving model to run/vae/0002_digits\weights/weights-114-43.77.h5
#
# Epoch 00114: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 115/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 43.7744 - vae_r_loss: 38.3907 - vae_kl_loss: 5.3837
#
# Epoch 00115: saving model to run/vae/0002_digits\weights/weights-115-43.77.h5
#
# Epoch 00115: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 116/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.7264 - vae_r_loss: 38.3467 - vae_kl_loss: 5.3797
#
# Epoch 00116: saving model to run/vae/0002_digits\weights/weights-116-43.73.h5
#
# Epoch 00116: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 117/200
# 60000/60000 [==============================] - 13s 225us/step - loss: 43.7909 - vae_r_loss: 38.3948 - vae_kl_loss: 5.3960
#
# Epoch 00117: saving model to run/vae/0002_digits\weights/weights-117-43.79.h5
#
# Epoch 00117: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 118/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.7505 - vae_r_loss: 38.3568 - vae_kl_loss: 5.3937
#
# Epoch 00118: saving model to run/vae/0002_digits\weights/weights-118-43.75.h5
#
# Epoch 00118: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 119/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.7563 - vae_r_loss: 38.3498 - vae_kl_loss: 5.4065
#
# Epoch 00119: saving model to run/vae/0002_digits\weights/weights-119-43.76.h5
#
# Epoch 00119: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 120/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.7009 - vae_r_loss: 38.2959 - vae_kl_loss: 5.4050
#
# Epoch 00120: saving model to run/vae/0002_digits\weights/weights-120-43.70.h5
#
# Epoch 00120: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 121/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.7213 - vae_r_loss: 38.3169 - vae_kl_loss: 5.4044
#
# Epoch 00121: saving model to run/vae/0002_digits\weights/weights-121-43.72.h5
#
# Epoch 00121: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 122/200
# 60000/60000 [==============================] - 14s 225us/step - loss: 43.6831 - vae_r_loss: 38.2600 - vae_kl_loss: 5.4231
#
# Epoch 00122: saving model to run/vae/0002_digits\weights/weights-122-43.68.h5
#
# Epoch 00122: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 123/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.6896 - vae_r_loss: 38.2823 - vae_kl_loss: 5.4073
#
# Epoch 00123: saving model to run/vae/0002_digits\weights/weights-123-43.69.h5
#
# Epoch 00123: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 124/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.7072 - vae_r_loss: 38.2984 - vae_kl_loss: 5.4088
#
# Epoch 00124: saving model to run/vae/0002_digits\weights/weights-124-43.71.h5
#
# Epoch 00124: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 125/200
# 60000/60000 [==============================] - 14s 225us/step - loss: 43.6641 - vae_r_loss: 38.2578 - vae_kl_loss: 5.4063
#
# Epoch 00125: saving model to run/vae/0002_digits\weights/weights-125-43.66.h5
#
# Epoch 00125: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 126/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.6889 - vae_r_loss: 38.2793 - vae_kl_loss: 5.4096
#
# Epoch 00126: saving model to run/vae/0002_digits\weights/weights-126-43.69.h5
#
# Epoch 00126: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 127/200
# 60000/60000 [==============================] - 14s 225us/step - loss: 43.6647 - vae_r_loss: 38.2651 - vae_kl_loss: 5.3996
#
# Epoch 00127: saving model to run/vae/0002_digits\weights/weights-127-43.66.h5
#
# Epoch 00127: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 128/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.6599 - vae_r_loss: 38.2571 - vae_kl_loss: 5.4027
#
# Epoch 00128: saving model to run/vae/0002_digits\weights/weights-128-43.66.h5
#
# Epoch 00128: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 129/200
# 60000/60000 [==============================] - 14s 225us/step - loss: 43.6822 - vae_r_loss: 38.2689 - vae_kl_loss: 5.4134
#
# Epoch 00129: saving model to run/vae/0002_digits\weights/weights-129-43.68.h5
#
# Epoch 00129: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 130/200
# 60000/60000 [==============================] - 13s 225us/step - loss: 43.6432 - vae_r_loss: 38.2311 - vae_kl_loss: 5.4121
#
# Epoch 00130: saving model to run/vae/0002_digits\weights/weights-130-43.64.h5
#
# Epoch 00130: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 131/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.6317 - vae_r_loss: 38.2024 - vae_kl_loss: 5.4292
#
# Epoch 00131: saving model to run/vae/0002_digits\weights/weights-131-43.63.h5
#
# Epoch 00131: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 132/200
# 60000/60000 [==============================] - 14s 225us/step - loss: 43.6551 - vae_r_loss: 38.2379 - vae_kl_loss: 5.4171
#
# Epoch 00132: saving model to run/vae/0002_digits\weights/weights-132-43.66.h5
#
# Epoch 00132: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 133/200
# 60000/60000 [==============================] - 14s 225us/step - loss: 43.6525 - vae_r_loss: 38.2361 - vae_kl_loss: 5.4163
#
# Epoch 00133: saving model to run/vae/0002_digits\weights/weights-133-43.65.h5
#
# Epoch 00133: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 134/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.6264 - vae_r_loss: 38.2014 - vae_kl_loss: 5.4250
#
# Epoch 00134: saving model to run/vae/0002_digits\weights/weights-134-43.63.h5
#
# Epoch 00134: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 135/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.6163 - vae_r_loss: 38.1851 - vae_kl_loss: 5.4312
#
# Epoch 00135: saving model to run/vae/0002_digits\weights/weights-135-43.62.h5
#
# Epoch 00135: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 136/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.6197 - vae_r_loss: 38.1837 - vae_kl_loss: 5.4360
#
# Epoch 00136: saving model to run/vae/0002_digits\weights/weights-136-43.62.h5
#
# Epoch 00136: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 137/200
# 60000/60000 [==============================] - 14s 226us/step - loss: 43.6152 - vae_r_loss: 38.1857 - vae_kl_loss: 5.4295
#
# Epoch 00137: saving model to run/vae/0002_digits\weights/weights-137-43.62.h5
#
# Epoch 00137: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 138/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.5952 - vae_r_loss: 38.1678 - vae_kl_loss: 5.4274
#
# Epoch 00138: saving model to run/vae/0002_digits\weights/weights-138-43.60.h5
#
# Epoch 00138: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 139/200
# 60000/60000 [==============================] - 14s 227us/step - loss: 43.6233 - vae_r_loss: 38.1860 - vae_kl_loss: 5.4373
#
# Epoch 00139: saving model to run/vae/0002_digits\weights/weights-139-43.62.h5
#
# Epoch 00139: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 140/200
# 60000/60000 [==============================] - 14s 236us/step - loss: 43.5834 - vae_r_loss: 38.1513 - vae_kl_loss: 5.4321
#
# Epoch 00140: saving model to run/vae/0002_digits\weights/weights-140-43.58.h5
#
# Epoch 00140: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 141/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5613 - vae_r_loss: 38.1231 - vae_kl_loss: 5.4381
#
# Epoch 00141: saving model to run/vae/0002_digits\weights/weights-141-43.56.h5
#
# Epoch 00141: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 142/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.5628 - vae_r_loss: 38.1317 - vae_kl_loss: 5.4311
#
# Epoch 00142: saving model to run/vae/0002_digits\weights/weights-142-43.56.h5
#
# Epoch 00142: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 143/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5915 - vae_r_loss: 38.1544 - vae_kl_loss: 5.4371
#
# Epoch 00143: saving model to run/vae/0002_digits\weights/weights-143-43.59.h5
#
# Epoch 00143: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 144/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.5790 - vae_r_loss: 38.1481 - vae_kl_loss: 5.4309
#
# Epoch 00144: saving model to run/vae/0002_digits\weights/weights-144-43.58.h5
#
# Epoch 00144: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 145/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5445 - vae_r_loss: 38.1091 - vae_kl_loss: 5.4353
#
# Epoch 00145: saving model to run/vae/0002_digits\weights/weights-145-43.54.h5
#
# Epoch 00145: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 146/200
# 60000/60000 [==============================] - 14s 235us/step - loss: 43.5432 - vae_r_loss: 38.0968 - vae_kl_loss: 5.4464
#
# Epoch 00146: saving model to run/vae/0002_digits\weights/weights-146-43.54.h5
#
# Epoch 00146: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 147/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5064 - vae_r_loss: 38.0705 - vae_kl_loss: 5.4359
#
# Epoch 00147: saving model to run/vae/0002_digits\weights/weights-147-43.51.h5
#
# Epoch 00147: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 148/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5641 - vae_r_loss: 38.1169 - vae_kl_loss: 5.4472
#
# Epoch 00148: saving model to run/vae/0002_digits\weights/weights-148-43.56.h5
#
# Epoch 00148: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 149/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5058 - vae_r_loss: 38.0586 - vae_kl_loss: 5.4472
#
# Epoch 00149: saving model to run/vae/0002_digits\weights/weights-149-43.51.h5
#
# Epoch 00149: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 150/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.4587 - vae_r_loss: 38.0176 - vae_kl_loss: 5.4411
#
# Epoch 00150: saving model to run/vae/0002_digits\weights/weights-150-43.46.h5
#
# Epoch 00150: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 151/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5392 - vae_r_loss: 38.0792 - vae_kl_loss: 5.4601
#
# Epoch 00151: saving model to run/vae/0002_digits\weights/weights-151-43.54.h5
#
# Epoch 00151: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 152/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.4818 - vae_r_loss: 38.0304 - vae_kl_loss: 5.4514
#
# Epoch 00152: saving model to run/vae/0002_digits\weights/weights-152-43.48.h5
#
# Epoch 00152: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 153/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.5225 - vae_r_loss: 38.0766 - vae_kl_loss: 5.4459
#
# Epoch 00153: saving model to run/vae/0002_digits\weights/weights-153-43.52.h5
#
# Epoch 00153: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 154/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4682 - vae_r_loss: 38.0233 - vae_kl_loss: 5.4450
#
# Epoch 00154: saving model to run/vae/0002_digits\weights/weights-154-43.47.h5
#
# Epoch 00154: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 155/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.5032 - vae_r_loss: 38.0556 - vae_kl_loss: 5.4476
#
# Epoch 00155: saving model to run/vae/0002_digits\weights/weights-155-43.50.h5
#
# Epoch 00155: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 156/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4689 - vae_r_loss: 38.0189 - vae_kl_loss: 5.4500
#
# Epoch 00156: saving model to run/vae/0002_digits\weights/weights-156-43.47.h5
#
# Epoch 00156: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 157/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.5142 - vae_r_loss: 38.0669 - vae_kl_loss: 5.4473
#
# Epoch 00157: saving model to run/vae/0002_digits\weights/weights-157-43.51.h5
#
# Epoch 00157: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 158/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4342 - vae_r_loss: 37.9950 - vae_kl_loss: 5.4392
#
# Epoch 00158: saving model to run/vae/0002_digits\weights/weights-158-43.43.h5
#
# Epoch 00158: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 159/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4750 - vae_r_loss: 38.0152 - vae_kl_loss: 5.4598
#
# Epoch 00159: saving model to run/vae/0002_digits\weights/weights-159-43.48.h5
#
# Epoch 00159: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 160/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4282 - vae_r_loss: 37.9594 - vae_kl_loss: 5.4688
#
# Epoch 00160: saving model to run/vae/0002_digits\weights/weights-160-43.43.h5
#
# Epoch 00160: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 161/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4840 - vae_r_loss: 38.0220 - vae_kl_loss: 5.4620
#
# Epoch 00161: saving model to run/vae/0002_digits\weights/weights-161-43.48.h5
#
# Epoch 00161: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 162/200
# 60000/60000 [==============================] - 14s 234us/step - loss: 43.4355 - vae_r_loss: 37.9889 - vae_kl_loss: 5.4466
#
# Epoch 00162: saving model to run/vae/0002_digits\weights/weights-162-43.44.h5
#
# Epoch 00162: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 163/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4194 - vae_r_loss: 37.9447 - vae_kl_loss: 5.4747
#
# Epoch 00163: saving model to run/vae/0002_digits\weights/weights-163-43.42.h5
#
# Epoch 00163: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 164/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4517 - vae_r_loss: 37.9902 - vae_kl_loss: 5.4616
#
# Epoch 00164: saving model to run/vae/0002_digits\weights/weights-164-43.45.h5
#
# Epoch 00164: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 165/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4267 - vae_r_loss: 37.9606 - vae_kl_loss: 5.4661
#
# Epoch 00165: saving model to run/vae/0002_digits\weights/weights-165-43.43.h5
#
# Epoch 00165: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 166/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4241 - vae_r_loss: 37.9671 - vae_kl_loss: 5.4570
#
# Epoch 00166: saving model to run/vae/0002_digits\weights/weights-166-43.42.h5
#
# Epoch 00166: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 167/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4126 - vae_r_loss: 37.9545 - vae_kl_loss: 5.4581
#
# Epoch 00167: saving model to run/vae/0002_digits\weights/weights-167-43.41.h5
#
# Epoch 00167: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 168/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4255 - vae_r_loss: 37.9501 - vae_kl_loss: 5.4755
#
# Epoch 00168: saving model to run/vae/0002_digits\weights/weights-168-43.43.h5
#
# Epoch 00168: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 169/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3907 - vae_r_loss: 37.9218 - vae_kl_loss: 5.4689
#
# Epoch 00169: saving model to run/vae/0002_digits\weights/weights-169-43.39.h5
#
# Epoch 00169: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 170/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3901 - vae_r_loss: 37.9171 - vae_kl_loss: 5.4730
#
# Epoch 00170: saving model to run/vae/0002_digits\weights/weights-170-43.39.h5
#
# Epoch 00170: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 171/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4080 - vae_r_loss: 37.9479 - vae_kl_loss: 5.4601
#
# Epoch 00171: saving model to run/vae/0002_digits\weights/weights-171-43.41.h5
#
# Epoch 00171: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 172/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3857 - vae_r_loss: 37.9056 - vae_kl_loss: 5.4802
#
# Epoch 00172: saving model to run/vae/0002_digits\weights/weights-172-43.39.h5
#
# Epoch 00172: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 173/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3706 - vae_r_loss: 37.8919 - vae_kl_loss: 5.4786
#
# Epoch 00173: saving model to run/vae/0002_digits\weights/weights-173-43.37.h5
#
# Epoch 00173: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 174/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.4092 - vae_r_loss: 37.9353 - vae_kl_loss: 5.4739
#
# Epoch 00174: saving model to run/vae/0002_digits\weights/weights-174-43.41.h5
#
# Epoch 00174: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 175/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3800 - vae_r_loss: 37.9142 - vae_kl_loss: 5.4657
#
# Epoch 00175: saving model to run/vae/0002_digits\weights/weights-175-43.38.h5
#
# Epoch 00175: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 176/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.4013 - vae_r_loss: 37.9217 - vae_kl_loss: 5.4796
#
# Epoch 00176: saving model to run/vae/0002_digits\weights/weights-176-43.40.h5
#
# Epoch 00176: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 177/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3359 - vae_r_loss: 37.8639 - vae_kl_loss: 5.4720
#
# Epoch 00177: saving model to run/vae/0002_digits\weights/weights-177-43.34.h5
#
# Epoch 00177: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 178/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3412 - vae_r_loss: 37.8690 - vae_kl_loss: 5.4722
#
# Epoch 00178: saving model to run/vae/0002_digits\weights/weights-178-43.34.h5
#
# Epoch 00178: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 179/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3841 - vae_r_loss: 37.9026 - vae_kl_loss: 5.4815
#
# Epoch 00179: saving model to run/vae/0002_digits\weights/weights-179-43.38.h5
#
# Epoch 00179: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 180/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3571 - vae_r_loss: 37.8815 - vae_kl_loss: 5.4756
#
# Epoch 00180: saving model to run/vae/0002_digits\weights/weights-180-43.36.h5
#
# Epoch 00180: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 181/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3414 - vae_r_loss: 37.8631 - vae_kl_loss: 5.4783
#
# Epoch 00181: saving model to run/vae/0002_digits\weights/weights-181-43.34.h5
#
# Epoch 00181: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 182/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3081 - vae_r_loss: 37.8317 - vae_kl_loss: 5.4764
#
# Epoch 00182: saving model to run/vae/0002_digits\weights/weights-182-43.31.h5
#
# Epoch 00182: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 183/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3155 - vae_r_loss: 37.8414 - vae_kl_loss: 5.4741
#
# Epoch 00183: saving model to run/vae/0002_digits\weights/weights-183-43.32.h5
#
# Epoch 00183: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 184/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.3338 - vae_r_loss: 37.8460 - vae_kl_loss: 5.4878
#
# Epoch 00184: saving model to run/vae/0002_digits\weights/weights-184-43.33.h5
#
# Epoch 00184: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 185/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3053 - vae_r_loss: 37.8192 - vae_kl_loss: 5.4861
#
# Epoch 00185: saving model to run/vae/0002_digits\weights/weights-185-43.31.h5
#
# Epoch 00185: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 186/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3409 - vae_r_loss: 37.8609 - vae_kl_loss: 5.4800
#
# Epoch 00186: saving model to run/vae/0002_digits\weights/weights-186-43.34.h5
#
# Epoch 00186: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 187/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3106 - vae_r_loss: 37.8183 - vae_kl_loss: 5.4923
#
# Epoch 00187: saving model to run/vae/0002_digits\weights/weights-187-43.31.h5
#
# Epoch 00187: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 188/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.2945 - vae_r_loss: 37.8073 - vae_kl_loss: 5.4872
#
# Epoch 00188: saving model to run/vae/0002_digits\weights/weights-188-43.29.h5
#
# Epoch 00188: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 189/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.3076 - vae_r_loss: 37.8227 - vae_kl_loss: 5.4849
#
# Epoch 00189: saving model to run/vae/0002_digits\weights/weights-189-43.31.h5
#
# Epoch 00189: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 190/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.2815 - vae_r_loss: 37.7888 - vae_kl_loss: 5.4927
#
# Epoch 00190: saving model to run/vae/0002_digits\weights/weights-190-43.28.h5
#
# Epoch 00190: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 191/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.2859 - vae_r_loss: 37.7958 - vae_kl_loss: 5.4901
#
# Epoch 00191: saving model to run/vae/0002_digits\weights/weights-191-43.29.h5
#
# Epoch 00191: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 192/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.2956 - vae_r_loss: 37.8147 - vae_kl_loss: 5.4809
#
# Epoch 00192: saving model to run/vae/0002_digits\weights/weights-192-43.30.h5
#
# Epoch 00192: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 193/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 43.2960 - vae_r_loss: 37.8097 - vae_kl_loss: 5.4863
#
# Epoch 00193: saving model to run/vae/0002_digits\weights/weights-193-43.30.h5
#
# Epoch 00193: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 194/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 43.2512 - vae_r_loss: 37.7648 - vae_kl_loss: 5.4864
#
# Epoch 00194: saving model to run/vae/0002_digits\weights/weights-194-43.25.h5
#
# Epoch 00194: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 195/200
# 60000/60000 [==============================] - 14s 233us/step - loss: 43.2660 - vae_r_loss: 37.7746 - vae_kl_loss: 5.4915
#
# Epoch 00195: saving model to run/vae/0002_digits\weights/weights-195-43.27.h5
#
# Epoch 00195: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 196/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.2876 - vae_r_loss: 37.8001 - vae_kl_loss: 5.4876
#
# Epoch 00196: saving model to run/vae/0002_digits\weights/weights-196-43.29.h5
#
# Epoch 00196: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 197/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.2619 - vae_r_loss: 37.7759 - vae_kl_loss: 5.4861
#
# Epoch 00197: saving model to run/vae/0002_digits\weights/weights-197-43.26.h5
#
# Epoch 00197: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 198/200
# 60000/60000 [==============================] - 14s 232us/step - loss: 43.2650 - vae_r_loss: 37.7673 - vae_kl_loss: 5.4978
#
# Epoch 00198: saving model to run/vae/0002_digits\weights/weights-198-43.27.h5
#
# Epoch 00198: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 199/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 43.2305 - vae_r_loss: 37.7290 - vae_kl_loss: 5.5016
#
# Epoch 00199: saving model to run/vae/0002_digits\weights/weights-199-43.23.h5
#
# Epoch 00199: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 200/200
# 60000/60000 [==============================] - 14s 231us/step - loss: 43.2498 - vae_r_loss: 37.7546 - vae_kl_loss: 5.4953
#
# Epoch 00200: saving model to run/vae/0002_digits\weights/weights-200-43.25.h5
#
# Epoch 00200: saving model to run/vae/0002_digits\weights/weights.h5
